# %% [markdown]
# # Bowling Statistics

# %% [markdown]
# This is an expermient of cricket analysis using my own bowling statistics that I simply copied into a CSV format from play-cricket.com to use in this notebook. This week I plan to learn how to web scrape all my cricket statistics from the last 10+ years and uncover hidden insights from that data, that can also automatically update as I play more games.
#
# I will then implement machine learning models to assess how I could potentially play in the future and continue the process with more players from the club.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bowling_df = pd.read_csv("Bowling Stats.csv", index_col="Season")
bowling_df.head()
# Out:
#         Overs  Wickets Best Bowling  5 Wicket Hauls  Economy Rate  \
# Season
# All     473.5       79          3/0               0          4.77
# 2024     15.0        3         2/18               0          4.47
# 2023     35.1        6         2/18               0          4.26
# 2022     97.2       13         3/14               0          3.77
# 2021     21.0        3          2/6               0          2.33
#
#         Strike Rate  Average  %Team Wickets
# Season
# All           33.25    26.44          14.93
# 2024          30.00    22.33          16.67
# 2023          35.17    25.00          17.14
# 2022          44.92    28.23          14.44
# 2021          42.00    16.33          15.00

# %%
bowling_df.shape
# Out:
# (13, 8)

# %%
bowling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, All to 2013
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Overs           13 non-null     float64
#  1   Wickets         13 non-null     int64
#  2   Best Bowling    13 non-null     object
#  3   5 Wicket Hauls  13 non-null     int64
#  4   Economy Rate    13 non-null     float64
#  5   Strike Rate     13 non-null     float64
#  6   Average         13 non-null     float64
#  7   %Team Wickets   13 non-null     float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 936.0+ bytes

# %%
bowling_df.describe()
# Out:
#             Overs    Wickets  5 Wicket Hauls  Economy Rate  Strike Rate  \
# count   13.000000  13.000000            13.0     13.000000    13.000000
# mean    70.015385  12.153846             0.0      5.202308    33.785385
# std    124.389763  20.550126             0.0      1.564945    15.101594
# min      7.000000   2.000000             0.0      2.330000    10.500000
# 25%     15.000000   3.000000             0.0      4.460000    28.470000
# 50%     30.000000   6.000000             0.0      4.770000    33.250000
# 75%     57.500000   9.000000             0.0      5.930000    42.000000
# max    473.500000  79.000000             0.0      8.140000    69.400000
#
#          Average  %Team Wickets
# count  13.000000      13.000000
# mean   28.600000      15.300769
# std    16.162109       6.115578
# min    10.330000       7.690000
# 25%    20.500000      11.110000
# 50%    25.000000      14.930000
# 75%    28.230000      17.140000
# max    68.600000      30.770000

# %%
reduced_df = bowling_df[1:]
reduced_df.head()
# Out:
#         Overs  Wickets Best Bowling  5 Wicket Hauls  Economy Rate  \
# Season
# 2024     15.0        3         2/18               0          4.47
# 2023     35.1        6         2/18               0          4.26
# 2022     97.2       13         3/14               0          3.77
# 2021     21.0        3          2/6               0          2.33
# 2020     30.0        8         3/30               0          5.47
#
#         Strike Rate  Average  %Team Wickets
# Season
# 2024          30.00    22.33          16.67
# 2023          35.17    25.00          17.14
# 2022          44.92    28.23          14.44
# 2021          42.00    16.33          15.00
# 2020          22.50    20.50          30.77

# %%
reduced_df = reduced_df.drop("5 Wicket Hauls", axis=1)
reduced_df = reduced_df.drop("Best Bowling", axis=1)
correlation = reduced_df.corr()
correlation
# Out:
#                   Overs   Wickets  Economy Rate  Strike Rate   Average  \
# Overs          1.000000  0.849164     -0.394193     0.433658  0.184944
# Wickets        0.849164  1.000000     -0.339986    -0.057894 -0.219059
# Economy Rate  -0.394193 -0.339986      1.000000    -0.193819  0.347496
# Strike Rate    0.433658 -0.057894     -0.193819     1.000000  0.830689
# Average        0.184944 -0.219059      0.347496     0.830689  1.000000
# %Team Wickets  0.023088  0.346186     -0.383927    -0.490905 -0.602970
#
#                %Team Wickets
# Overs               0.023088
# Wickets             0.346186
# Economy Rate       -0.383927
# Strike Rate        -0.490905
# Average            -0.602970
# %Team Wickets       1.000000

# %%
sns.heatmap(correlation, cmap='viridis', annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(reduced_df)
